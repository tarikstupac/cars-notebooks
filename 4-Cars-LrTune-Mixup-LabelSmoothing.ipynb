# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tarfile
import scipy.io as sio
import numpy as np
import os
import cv2 as cv
import shutil
import random
from pathlib import Path
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Morningstar\\Documents\\CARSv2'

# %%
from utils import get_path, get_x, get_y, show_img, draw_outline, draw_rect, draw_text, crop, compare_top_losses, compare_most_confused

# %%
path = get_path();path
# Out:
# Path('C:/Users/Morningstar/Documents/CARSv2')

# %%
list(path.iterdir())
# Out:
# [WindowsPath('C:/Users/Morningstar/Documents/CARSv2/.ipynb_checkpoints'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/1-CarsBaseline.ipynb'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/2-CarsBaseline-ImgScaling.ipynb'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/3-Cars-ImgScaling-LrRatesTuning.ipynb'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/CarsBasic.ipynb'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/CarsBasicv2-BasicResNet50.ipynb'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/CarsBasicv2-TRES.ipynb'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/CarsBasicv2.ipynb'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/cars_annos.mat'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/cars_meta.mat'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/cars_test_annos.mat'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/cars_test_annos_withlabels.mat'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/cars_train_annos.mat'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/data'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/labels_with_annos.csv'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/merged'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/models'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/test'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/test_labels_with_annos.csv'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/train'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/train_labels_with_annos.csv'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/utils.py'),
#  WindowsPath('C:/Users/Morningstar/Documents/CARSv2/__pycache__')]

# %%
cars_test = Path(path/'test')
cars_train = Path(path/'train')

# %%
len(list(cars_test.iterdir()))
len(list(cars_train.iterdir()))
# Out:
# 8144

# %% [markdown]
# # Ucitavanje i kreiranje DataBlock i DataLoaders objekta

# %%
from fastai.vision.all import *
from fastai.metrics import error_rate
from fastai import *
import cv2 as cv
import numpy as np
import pandas as pd
import scipy.io as sio
from PIL import Image
import timm
from wwf.vision.timm import *
import torch
import torchvision
import random
from torch.distributions.beta import Beta

# %%
def random_seed(seed_value, use_cuda):
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    random.seed(seed_value) # Python
    if use_cuda: 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
        torch.backends.cudnn.deterministic = True  #needed
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# Ucitavanje pandas dataframe-ova

# %%
labels_df = pd.read_csv(path/'labels_with_annos.csv')
train_labels_df = pd.read_csv(path/'train_labels_with_annos.csv')
test_labels_df = pd.read_csv(path/'test_labels_with_annos.csv')

# %%
labels_df.head(10)
# Out:
#     filename  bbox_x1  bbox_y1  bbox_x2  bbox_y2  class_id  \
# 0  00001.jpg       39      116      569      375        14
# 1  00002.jpg       36      116      868      587         3
# 2  00003.jpg       85      109      601      381        91
# 3  00004.jpg      621      393     1484     1096       134
# 4  00005.jpg       14       36      133       99       106
# 5  00006.jpg      259      289      515      416       123
# 6  00007.jpg       88       80      541      397        89
# 7  00008.jpg       73       79      591      410        96
# 8  00009.jpg       20      126     1269      771       167
# 9  00010.jpg       21      110      623      367        58
#
#                             class_name  is_test   filename_cropped  bbox_h  \
# 0                  Audi TTS Coupe 2012        0  cropped_00001.jpg     260
# 1                  Acura TL Sedan 2012        0  cropped_00002.jpg     472
# 2           Dodge Dakota Club Cab 2007        0  cropped_00003.jpg     273
# 3     Hyundai Sonata Hybrid Sedan 2012        0  cropped_00004.jpg     704
# 4  Ford F-450 Super Duty Crew Cab 2012        0  cropped_00005.jpg      64
# 5           Geo Metro Convertible 1993        0  cropped_00006.jpg     128
# 6               Dodge Journey SUV 2012        0  cropped_00007.jpg     318
# 7             Dodge Charger Sedan 2012        0  cropped_00008.jpg     332
# 8         Mitsubishi Lancer Sedan 2012        0  cropped_00009.jpg     646
# 9          Chevrolet Traverse SUV 2012        0  cropped_00010.jpg     258
#
#    bbox_w
# 0     531
# 1     833
# 2     517
# 3     864
# 4     120
# 5     257
# 6     454
# 7     519
# 8    1250
# 9     603

# %%
train_labels_df.head(10)
# Out:
#     filename                           class_name  class_id
# 0  00001.jpg                  Audi TTS Coupe 2012        14
# 1  00002.jpg                  Acura TL Sedan 2012         3
# 2  00003.jpg           Dodge Dakota Club Cab 2007        91
# 3  00004.jpg     Hyundai Sonata Hybrid Sedan 2012       134
# 4  00005.jpg  Ford F-450 Super Duty Crew Cab 2012       106
# 5  00006.jpg           Geo Metro Convertible 1993       123
# 6  00007.jpg               Dodge Journey SUV 2012        89
# 7  00008.jpg             Dodge Charger Sedan 2012        96
# 8  00009.jpg         Mitsubishi Lancer Sedan 2012       167
# 9  00010.jpg          Chevrolet Traverse SUV 2012        58

# %%
test_labels_df.head(10)
# Out:
#          filename                              class_name  class_id  vocab_id
# 0  test_00001.jpg                 Suzuki Aerio Sedan 2007       181       180
# 1  test_00002.jpg     Ferrari 458 Italia Convertible 2012       103       100
# 2  test_00003.jpg                   Jeep Patriot SUV 2012       145       147
# 3  test_00004.jpg                 Toyota Camry Sedan 2012       187       186
# 4  test_00005.jpg                Tesla Model S Sedan 2012       185       184
# 5  test_00006.jpg  Chrysler Town and Country Minivan 2012        78        80
# 6  test_00007.jpg                    GMC Terrain SUV 2012       118       120
# 7  test_00008.jpg        Mercedes-Benz S-Class Sedan 2012       165       163
# 8  test_00009.jpg                         BMW X5 SUV 2007        32        35
# 9  test_00010.jpg                   Chevrolet HHR SS 2010        60        61

# %% [markdown]
# Funkcija za dobavljanje dataloaders objekta na osnovu velicine slike, batch size i seed parametra.

# %%
def get_dls(size,bs,seed):
    random_seed(seed,True)
    augs = [*aug_transforms(size=size, min_scale=0.75),Normalize.from_stats(*imagenet_stats),ToTensor()]
    
    dblock= DataBlock((ImageBlock, CategoryBlock),
                  splitter=RandomSplitter(seed=seed),
                  get_x=get_x, 
                  get_y=get_y,
                  item_tfms=[Resize(460, method='squish'),ToTensor()],
                  batch_tfms=augs)
    dls = dblock.dataloaders(train_labels_df, bs=bs, num_workers=0)
    return dls

# %% [markdown]
# # Label smoothing + MixUp

# %% [markdown]
# U ovoj varijanti cemo kombinirati label smoothing loss funkciju sa MixUp regularizacijom i velikim brojem trening epoha da bi ove dvije metode imali sto bolji efekat. Ova varijanta nece sadrzavati progresivno skaliranje velicine slika.

# %% [markdown]
# Sada mozemo vidjeti kako izgledaju podatci u nasem DataLoader-u tako sto ucitamo jedan batch.

# %%
size = 224
bs = 64
seed = 42
dls = get_dls(size, bs, seed)

# %%
dls.show_batch(nrows=2, ncols=6)

# %% [markdown]
# ## Kreiranje modela

# %% [markdown]
# Kreiramo model koristeci ResNet50 arhitekturu sa Label Smoothing loss funkcijom i Mixup regularizacijom.
# Kao optimizator se koristi Adam, a u jednoj od slijedecih varijanti cemo primjeniti drugi optimizator koji je specificno dobar u kombinaciji sa Label Smoothing i Mixupom i velikim brojem epoha u treningu
#
# Kao metrika po kojoj cemo pratiti trening koristimo preciznost(accuracy).
#
# Dio to_fp16() definira mixed precision trening koji ubrzava trening na određenim grafickim karticama kao sto je moja RTX 2060 Super.

# %%
learn = cnn_learner(dls, resnet50, metrics=accuracy, cbs=MixUp, loss_func= LabelSmoothingCrossEntropyFlat()).to_fp16()

# %% [markdown]
# Nakon kreiranja modela mozemo krenuti sa treningom.

# %% [markdown]
# ## Treniranje modela

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.003981071710586548, lr_steep=0.019054606556892395)

# %%
learn.fine_tune(40,4e-3, freeze_epochs=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.578084</td>
#       <td>4.922747</td>
#       <td>0.063268</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.682400</td>
#       <td>4.117060</td>
#       <td>0.184275</td>
#       <td>04:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.997837</td>
#       <td>3.718752</td>
#       <td>0.253686</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.576037</td>
#       <td>3.502614</td>
#       <td>0.281327</td>
#       <td>04:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.171957</td>
#       <td>3.195443</td>
#       <td>0.343366</td>
#       <td>04:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.909152</td>
#       <td>2.987908</td>
#       <td>0.411548</td>
#       <td>04:22</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.736344</td>
#       <td>2.866484</td>
#       <td>0.432432</td>
#       <td>04:12</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.559591</td>
#       <td>2.718871</td>
#       <td>0.491400</td>
#       <td>04:15</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.426353</td>
#       <td>2.577009</td>
#       <td>0.530713</td>
#       <td>04:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.314553</td>
#       <td>2.470891</td>
#       <td>0.557740</td>
#       <td>03:58</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.004210</td>
#       <td>2.215894</td>
#       <td>0.632064</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.808654</td>
#       <td>2.071960</td>
#       <td>0.682432</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.704670</td>
#       <td>1.991027</td>
#       <td>0.703931</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.616021</td>
#       <td>1.949965</td>
#       <td>0.710074</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.568603</td>
#       <td>1.907754</td>
#       <td>0.721744</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.541980</td>
#       <td>1.898138</td>
#       <td>0.730344</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.505983</td>
#       <td>1.861128</td>
#       <td>0.730344</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.497042</td>
#       <td>1.932381</td>
#       <td>0.714988</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.461056</td>
#       <td>1.855623</td>
#       <td>0.734029</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.474479</td>
#       <td>1.832983</td>
#       <td>0.743243</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.420028</td>
#       <td>1.800335</td>
#       <td>0.754914</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.396843</td>
#       <td>1.775544</td>
#       <td>0.762899</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.343703</td>
#       <td>1.712558</td>
#       <td>0.774570</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.325228</td>
#       <td>1.741256</td>
#       <td>0.783784</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.285532</td>
#       <td>1.739564</td>
#       <td>0.780098</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.246426</td>
#       <td>1.647213</td>
#       <td>0.797912</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.226754</td>
#       <td>1.614186</td>
#       <td>0.808968</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.183412</td>
#       <td>1.591506</td>
#       <td>0.821867</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.151668</td>
#       <td>1.600578</td>
#       <td>0.811425</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.130320</td>
#       <td>1.546816</td>
#       <td>0.841523</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.093081</td>
#       <td>1.579143</td>
#       <td>0.838452</td>
#       <td>04:10</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2.080428</td>
#       <td>1.526895</td>
#       <td>0.835995</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>2.054766</td>
#       <td>1.496967</td>
#       <td>0.848894</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2.000037</td>
#       <td>1.498588</td>
#       <td>0.857494</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.986485</td>
#       <td>1.519803</td>
#       <td>0.843980</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.975735</td>
#       <td>1.455838</td>
#       <td>0.861794</td>
#       <td>04:09</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.967885</td>
#       <td>1.456698</td>
#       <td>0.859951</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.958823</td>
#       <td>1.452653</td>
#       <td>0.870393</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.933141</td>
#       <td>1.437664</td>
#       <td>0.871007</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.929315</td>
#       <td>1.427258</td>
#       <td>0.878378</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.909572</td>
#       <td>1.435620</td>
#       <td>0.875921</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.886230</td>
#       <td>1.412094</td>
#       <td>0.878378</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.883717</td>
#       <td>1.406098</td>
#       <td>0.883907</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.879819</td>
#       <td>1.400923</td>
#       <td>0.878993</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.848720</td>
#       <td>1.404632</td>
#       <td>0.880835</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.832628</td>
#       <td>1.402439</td>
#       <td>0.880835</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.849155</td>
#       <td>1.398663</td>
#       <td>0.883292</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.871551</td>
#       <td>1.395107</td>
#       <td>0.888821</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.868212</td>
#       <td>1.392792</td>
#       <td>0.887592</td>
#       <td>04:09</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.848671</td>
#       <td>1.394012</td>
#       <td>0.885135</td>
#       <td>04:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage1-resnet50-mixuplabelsmooth-224px')
# Out:
# Path('models/stage1-resnet50-mixuplabelsmooth-224px.pth')

# %%
learn.load('stage1-resnet50-mixuplabelsmooth-224px')

# %% [markdown]
# # Rezulatati

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
compare_top_losses(10, interp, labels_df, 1, path=path)
# Out:
# PREDICTION:Dodge Journey SUV 2012, ACTUAL:Dodge Caliber Wagon 2012
# Loss: 6.83, Probability: 0.9082
# PREDICTION:Rolls-Royce Ghost Sedan 2012, ACTUAL:Scion xD Hatchback 2012
# Loss: 6.83, Probability: 1.5742
# PREDICTION:BMW 3 Series Sedan 2012, ACTUAL:BMW M5 Sedan 2010
# Loss: 6.29, Probability: -0.7139
# PREDICTION:Audi TTS Coupe 2012, ACTUAL:Audi TT Hatchback 2011
# Loss: 6.24, Probability: -0.6382
# PREDICTION:Acura TSX Sedan 2012, ACTUAL:Acura ZDX Hatchback 2012
# Loss: 6.15, Probability: -2.2695
# PREDICTION:Fisker Karma Sedan 2012, ACTUAL:Mitsubishi Lancer Sedan 2012
# Loss: 5.91, Probability: 0.8984
# PREDICTION:Audi 100 Sedan 1994, ACTUAL:Audi V8 Sedan 1994
# Loss: 5.87, Probability: 4.5547
# PREDICTION:Acura RL Sedan 2012, ACTUAL:Acura TSX Sedan 2012
# Loss: 5.76, Probability: -0.2488
# PREDICTION:Porsche Panamera Sedan 2012, ACTUAL:McLaren MP4-12C Coupe 2012
# Loss: 5.69, Probability: 1.1562
# PREDICTION:Ford Fiesta Sedan 2012, ACTUAL:Hyundai Azera Sedan 2012
# Loss: 5.61, Probability: 1.2217

# %% [markdown]
# # Testiranje na testnom setu podataka

# %% [markdown]
# Predikcija na samo jednoj slici iz testnog seta

# %%
test_labels_df.head()
# Out:
#          filename                           class_name  class_id  vocab_id
# 0  test_00001.jpg              Suzuki Aerio Sedan 2007       181       180
# 1  test_00002.jpg  Ferrari 458 Italia Convertible 2012       103       100
# 2  test_00003.jpg                Jeep Patriot SUV 2012       145       147
# 3  test_00004.jpg              Toyota Camry Sedan 2012       187       186
# 4  test_00005.jpg             Tesla Model S Sedan 2012       185       184

# %%
test_item = path/'merged'/test_labels_df['filename'][0]; test_item
# Out:
# Path('C:/Users/Morningstar/Documents/CARSv2/merged/test_00001.jpg')

# %%
pred_y,pred_idx,probs=learn.predict(test_item)

# %%
act_y_id = test_labels_df['vocab_id'][0]
act_y = test_labels_df['class_name'][0]

# %%
np.argmax(probs)
# Out:
# tensor(180)

# %%
pred_y,act_y
# Out:
# ("['smart fortwo Convertible 2012', 'Acura Integra Type R 2001', 'Acura Integra Type R 2001', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'Acura RL Sedan 2012', 'smart fortwo Convertible 2012', 'Volvo XC90 SUV 2007', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'Volvo XC90 SUV 2007', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'Volvo XC90 SUV 2007', 'AM General Hummer SUV 2000', 'Acura Integra Type R 2001', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'smart fortwo Convertible 2012', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'smart fortwo Convertible 2012', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'Acura RL Sedan 2012', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'Volvo XC90 SUV 2007', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'Acura Integra Type R 2001', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'Acura Integra Type R 2001', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'Acura Integra Type R 2001', 'Acura RL Sedan 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'Acura Integra Type R 2001', 'AM General Hummer SUV 2000', 'Acura Integra Type R 2001', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'Volvo C30 Hatchback 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'Volvo XC90 SUV 2007', 'smart fortwo Convertible 2012', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'Acura Integra Type R 2001', 'Acura Integra Type R 2001', 'smart fortwo Convertible 2012', 'smart fortwo Convertible 2012', 'smart fortwo Convertible 2012', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 2000', 'Volvo XC90 SUV 2007', 'AM General Hummer SUV 2000', 'AM General Hummer SUV 20 ...
#  'Suzuki Aerio Sedan 2007')

# %%
np.argmax(pred_idx),act_y_id
# Out:
# (tensor(180), 180)

# %% [markdown]
# Ucitavanje testnih itema na isti nacin kao sto smo ucitavali trening iteme kroz get_x funkciju

# %%
test_items = get_x(test_labels_df);test_items
# Out:
# 0       C:\Users\Morningstar\Documents\CARSv2\merged\test_00001.jpg
# 1       C:\Users\Morningstar\Documents\CARSv2\merged\test_00002.jpg
# 2       C:\Users\Morningstar\Documents\CARSv2\merged\test_00003.jpg
# 3       C:\Users\Morningstar\Documents\CARSv2\merged\test_00004.jpg
# 4       C:\Users\Morningstar\Documents\CARSv2\merged\test_00005.jpg
#                                    ...
# 8036    C:\Users\Morningstar\Documents\CARSv2\merged\test_08037.jpg
# 8037    C:\Users\Morningstar\Documents\CARSv2\merged\test_08038.jpg
# 8038    C:\Users\Morningstar\Documents\CARSv2\merged\test_08039.jpg
# 8039    C:\Users\Morningstar\Documents\CARSv2\merged\test_08040.jpg
# 8040    C:\Users\Morningstar\Documents\CARSv2\merged\test_08041.jpg
# Name: filename, Length: 8041, dtype: object

# %% [markdown]
# Kreiranje test dataloader objekta koji ce sadrzavati sve test iteme

# %%
test_dl = learn.dls.test_dl(test_items)

# %%
test_dl.show_batch()

# %% [markdown]
# Predikcije nad citavim test setom

# %%
preds = learn.get_preds(dl=test_dl)

# %% [markdown]
# Da bi provjerili tacnost na citavom datasetu prvo trebamo spasiti sve predikcije u jednu varijablu.
#
# Mozemo primjetiti oblik tensora za predikcije, koji je broj slika (8041) sa broj klasa (196), jer za svaku sliku sadrzava 196 vrijednosti koje izgledaju isto kao sto smo vidjeli iznad.

# %%
a = preds[0]; a.shape
# Out:
# torch.Size([8041, 196])

# %% [markdown]
# Zatim nam treba varijabla, tj tensor s kojim cemo porediti ove predikcije, odnosno onaj koji sadrzava stvarne vrijednosti klasa za slike iz test seta.
#
# Za te potrebe kreirat cemo numpy array koji cemo poslije pretvoriti u PyTorch tensor.

# %%
b = np.array(test_labels_df['vocab_id'],dtype=np.int)
b = torch.from_numpy(b);b.shape
# Out:
# torch.Size([8041])

# %% [markdown]
# Sve sto nam preostaje je da pozovemo accuracy funkciju koja ce za nas na proslijedenom tensoru a uraditi argmax funkciju i porediti sa proslijedenim tensorom b

# %%
accuracy(a,b)
# Out:
# tensor(0.8953)

# %% [markdown]
# Tacnost ovog modela na testnom setu podataka je 89.53% sto je najbolji rezultat do sada. Slijedeci korak je kombinirati ovaj proces sa skaliranjem slika i novim optimizatorom da vidimo mozemo li poboljšati rezultat.
#
# Jedna stvar koja je bitna za primjetiti je da je validacijski gubitak (val. loss) manji od trening gubitka (train. loss), sto je direktan rezultat regularizacije koja je sprijecila model da overfittuje na trening set.
